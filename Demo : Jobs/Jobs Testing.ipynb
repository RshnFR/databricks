# %%
# %fs ls "dbfs:/Volumes/workspace/learning/learn/retail/"

# %%
# %sql
FROM read_files("dbfs:/Volumes/workspace/learning/learn/retail/",
    format => "csv",
    rescuedDataColumn => "rescued")

# %%
# %sql
DROP TABLE learning.retail_store_sales_bronze
