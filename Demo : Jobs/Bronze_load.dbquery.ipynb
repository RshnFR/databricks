-- %%
DROP TABLE IF EXISTS learning.retail_store_sales_bronze;

CREATE TABLE learning.retail_store_sales_bronze
AS 
SELECT *
FROM read_files(
  "dbfs:/Volumes/workspace/learning/learn/retail",
  format => "csv",
  schema => "transaction_id STRING,
  customer_id STRING,
  category STRING,
  item STRING,
  price_per_unit FLOAT,
  quantity INT,
  total FLOAT,
  payment_method STRING,
  payment_location STRING,
  transaction_date DATE,
  discount_applied BOOLEAN"
  );
